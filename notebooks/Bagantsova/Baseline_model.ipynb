# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("maltegrosse/8-m-spotify-tracks-genre-audio-features")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/ilya/.cache/kagglehub/datasets/maltegrosse/8-m-spotify-tracks-genre-audio-features/versions/1

# %%
import pandas as pd
import sqlite3

db_path = path + "/spotify.sqlite"

# %%
con = sqlite3.connect(db_path)
con.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
cur = con.cursor()

cur.execute("SELECT name FROM sqlite_master  WHERE type='table';")
print(cur.fetchall())
# Out:
# [('albums',), ('artists',), ('audio_features',), ('genres',), ('r_albums_artists',), ('r_albums_tracks',), ('r_artist_genre',), ('r_track_artist',), ('tracks',)]

# %% [markdown]
# ### Загрузка данных из базы Kaggle. Можно пропустить, если есть сохраненный файл.

# %%
rAlbumsTracks = pd.read_sql_query("SELECT * FROM r_albums_tracks", con)
albums = pd.read_sql_query("SELECT * from albums", con)
artists = pd.read_sql_query("SELECT * from artists", con)
audio_features = pd.read_sql_query("SELECT * from audio_features", con)
tracks = pd.read_sql_query("SELECT * from tracks", con)
rAlbumsArtists = pd.read_sql_query("SELECT * from r_albums_artists", con)

# %%
albums = albums.sort_values(by='popularity',ascending=False)
albums_merge_artists = pd.merge(rAlbumsArtists,albums,left_on='album_id',right_on='id')
albums_merge_artists.drop(['id'],axis=1,inplace=True)
albums_merge_artists.sort_values(by='popularity',ascending=False,inplace=True)
albums_merge_artists.rename(columns={'name':'albumName'},inplace=True)
albums_merge_artists.drop_duplicates(subset=['albumName','artist_id'],inplace=True)

MergedData = pd.merge(rAlbumsTracks,albums_merge_artists[albums_merge_artists['album_type']!='single'])
MergedData = pd.merge(MergedData,audio_features,left_on='track_id',right_on='id')
MergedData = MergedData.drop(['id'],axis=1)
MergedData = pd.merge(MergedData,artists[['name','id']],left_on='artist_id',right_on='id')
MergedData = MergedData.drop(['id'],axis=1)
MergedData = MergedData.rename(columns={'name':'artistName'})
MergedData = MergedData.sort_values(by=['popularity'],ascending=False)

# %%
MergedData = MergedData[MergedData['release_date'] > -3000000000000]
MergedData['release_year'] = pd.to_datetime(MergedData['release_date'], unit='ms').dt.year

# %%
import pickle

def storeData(df):
    dbfile = open('MergedData','ab')
    pickle.dump(df, dbfile)
    dbfile.close()
storeData(MergedData)

# %% [markdown]
# ### Загрузка данных из сохраненного файла.

# %%
import pickle
    
def loadData():
    # for reading also binary mode is important
    dbfile = open('MergedData', 'rb')
    db = pickle.load(dbfile)
    dbfile.close()
    return db

# %%
MergedData = loadData()

# %%
MergedData.shape
# Out:
# (9182239, 24)

# %% [markdown]
# ### Кодируем категориальные признаки и пробуем порекомендовать

# %% [markdown]
# Мой ноут долго подгружает все-все данные, поэтому для эксперимента ниже захвачу только пару миллионов строк.

# %%
MergedData = MergedData.sample(int(2e6), random_state=42)

# %%
MergedData.shape
# Out:
# (2000000, 24)

# %%
rArtistGenre = pd.read_sql_query("SELECT * FROM r_artist_genre", con)
merged_generes_data = pd.merge(MergedData, rArtistGenre, on="artist_id", how="left")
known_genres = ['pop', 'rock', 'metal', 'rap', 'hip hop', 'classic', 'alt', 'jazz', 'indie']
def assign_main_genre(row):
    if isinstance(row['genre_id'], str):
        for genre in known_genres:
            if genre in row['genre_id']:
                return genre
    return 'others'

merged_generes_data['main_genre'] = merged_generes_data.apply(assign_main_genre, axis=1)

# %%
MergedData.shape
# Out:
# (2000000, 24)

# %%
merged_generes_data.nunique()
# Out:
# album_id             484394
# track_id            1898677
# artist_id            283802
# albumName            430304
# album_group               1
# album_type                2
# release_date          16867
# popularity               99
# acousticness           5398
# analysis_url        1898677
# danceability           1375
# duration             296554
# energy                 3608
# instrumentalness       5402
# key                      12
# liveness               1828
# loudness              41728
# mode                      2
# speechiness            1658
# tempo                149910
# time_signature            5
# valence                2491
# artistName           278734
# release_year            118
# genre_id               5458
# main_genre               10
# dtype: int64

# %% [markdown]
# Просто обалдеть, как много айди артистов и жанров. В первой версии закодируем артистов таким образом, чтоб они выступали в одном стиле - понятно, что это далеко не лучшая идея, но именно она позволяет в первом приближении протестировать бейзлайн. В дальнейшем нужно выгрузить из спотифая много плейлистов и посмотреть на состав артистов в нем. То же применимо и к жанрам из расширенного списка.

# %%
artist_playlists = []

for _, album_df in merged_generes_data.groupby('genre_id'):
    artist_playlists.append(list(album_df['artist_id'].unique()))

# %%
from gensim.models import Word2Vec
vector_size = 200
artist_model = Word2Vec(sentences=artist_playlists, vector_size=vector_size, window=5, min_count=1, sg=1)

# %%
merged_generes_data[merged_generes_data['artist_id'] == 
                   artist_model.wv.most_similar('1uNFoZAHBGtllmzznpCI3s')[0][0] # Justin Bieber
                   ]['artistName'].head(1)
# Out:
# 144101    Markus Johansson
# Name: artistName, dtype: object

# %% [markdown]
# Размер вектора надо еще крутить, но пока попробуем так.

# %%
import numpy as np

artist_embedding = MergedData['artist_id'].apply(
    lambda x: pd.Series(artist_model.wv[x]) if x in artist_model.wv else pd.Series(np.nan * np.zeros(vector_size)))
artist_embedding.columns = [f'artist_embedding_{e}' for e in range(vector_size)]

# %%
artist_embedding.head()
# Out:
#          artist_embedding_0  artist_embedding_1  artist_embedding_2  \
# 6465512                 NaN                 NaN                 NaN
# 7648496                 NaN                 NaN                 NaN
# 463458                  NaN                 NaN                 NaN
# 4955776                 NaN                 NaN                 NaN
# 7011397           -0.004242            0.000487           -0.003103
#
#          artist_embedding_3  artist_embedding_4  artist_embedding_5  \
# 6465512                 NaN                 NaN                 NaN
# 7648496                 NaN                 NaN                 NaN
# 463458                  NaN                 NaN                 NaN
# 4955776                 NaN                 NaN                 NaN
# 7011397           -0.001952           -0.000713           -0.002131
#
#          artist_embedding_6  artist_embedding_7  artist_embedding_8  \
# 6465512                 NaN                 NaN                 NaN
# 7648496                 NaN                 NaN                 NaN
# 463458                  NaN                 NaN                 NaN
# 4955776                 NaN                 NaN                 NaN
# 7011397            0.000788            0.001003            0.002345
#
#          artist_embedding_9  ...  artist_embedding_190  artist_embedding_191  \
# 6465512                 NaN  ...                   NaN                   NaN
# 7648496                 NaN  ...                   NaN                   NaN
# 463458                  NaN  ...                   NaN                   NaN
# 4955776                 NaN  ...                   NaN                   NaN
# 7011397           -0.004067  ...               0.00467             -0.004072
#
#          artist_embedding_192  artist_embedding_193  artist_embedding_194  \
# 6465512                   NaN                   NaN                   NaN
# 7648496                   NaN                   NaN                   NaN
# 463458                    NaN                   NaN                   NaN
# 4955776                   NaN                   NaN                   NaN
# 7011397              0.003893              0.003603              0.004268
#
#          artist_embedding_195  artist_embedding_196  artist_embedding_197  \
# 6465512                   NaN                   NaN                   NaN
# 7648496                   NaN                   NaN                   NaN
# 463458                    NaN                   NaN                   NaN
# 4955776                   NaN                   NaN                   NaN
# 7011397             -0.001558             -0.001455              0.004816
#
#          artist_embedding_198  artist_embedding_199
# 6465512                   NaN                   NaN
# 7648496                   NaN                   NaN
# 463458                    NaN                   NaN
# 4955776                   NaN                   NaN
# 7011397              -0.00277             -0.004483
#
# [5 rows x 200 columns]

# %%
genres = {}

for track_id, track_df in merged_generes_data.groupby('track_id'):
    genres[track_id] = dict.fromkeys(known_genres + ['others'], 0)
    for genre_id in list(track_df['main_genre'].unique()):
        if genre_id in genres[track_id]:
            genres[track_id][genre_id] = 1
genre_df = pd.DataFrame(genres).T

# %%
genre_df.head()
# Out:
#                         pop  rock  metal  rap  hip hop  classic  alt  jazz  \
# 0000pHgyPFaekcPYkSiZ5T    0     0      0    0        0        0    0     0
# 0000uJA4xCdxThagdLkkLR    0     0      0    0        0        0    0     0
# 0002UmhGH9V9BiMN9lyMHW    0     0      0    0        0        0    0     0
# 0006bYz7i78jMS4hiuGeJe    0     0      0    0        0        0    0     0
# 00075E86IyrXpuZcdibi60    0     0      0    0        0        0    0     0
#
#                         indie  others
# 0000pHgyPFaekcPYkSiZ5T      0       1
# 0000uJA4xCdxThagdLkkLR      0       1
# 0002UmhGH9V9BiMN9lyMHW      0       1
# 0006bYz7i78jMS4hiuGeJe      0       1
# 00075E86IyrXpuZcdibi60      0       1

# %%
MergedData = pd.concat([
    MergedData,
    artist_embedding,
        pd.merge(MergedData.reset_index(), 
         genre_df.reset_index().rename({'index': 'track_id'}, axis=1),
         on=['track_id'], how='left').set_index('index')[genre_df.columns],
    pd.get_dummies(MergedData['time_signature'], prefix='time_signature').astype(int),
    pd.get_dummies(MergedData['key'], prefix='key').astype(int),
    pd.get_dummies(MergedData['mode'], prefix='mode').astype(int),
    
], axis=1).dropna()

# %%
MergedData.shape
# Out:
# (1298012, 253)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

def content_based_recommendation(data, track_id, n=10):
    # Уберем лишние признаки, которые не будем использовать
    features = data.drop(
        ['album_id', 'track_id', 'artist_id', 'albumName', 'album_group', 
         'release_date', 'analysis_url', 'artistName', 'album_type',
         'key', 'mode', 'time_signature',
        ],
        axis=1,
    ).columns
    
    scaler = StandardScaler()
    
    # Нормализуем только нужные нам признаки
    data[features] = scaler.fit_transform(data[features])
    
    # Находим трек, похожий на track_id c помощью косинусного расстояния
    track_features = data[data['track_id'] == track_id][features].values
    all_features = data[features].values

    similarities = cosine_similarity(track_features, all_features).flatten()

    similar_indices = similarities.argsort()[-n-1:-1][::-1]
    similar_tracks = data.iloc[similar_indices]
    
    return similar_tracks

# %% [markdown]
# Возьмем в качестве примера какой-нибудь трек какого-нибудь популярного артиста, чтобы легко было угадать рекомендации. Попробуем The Weeknd https://open.spotify.com/track/6kWxIqQDsKFYCJGbU4AjCX.

# %%
pd.set_option('display.max_rows', 500)
MergedData[MergedData['track_id'] == '6kWxIqQDsKFYCJGbU4AjCX'].T
# Out:
#                                                                 2114509
# album_id                                         4yP0hdKOZPNshxUOjY0cZj
# track_id                                         6kWxIqQDsKFYCJGbU4AjCX
# artist_id                                        1Xyo4u8uXC1ZmMpatF05PJ
# albumName                                                   After Hours
# album_group
# album_type                                                        album
# release_date                                              1584662400000
# popularity                                                           97
# acousticness                                                     0.0909
# analysis_url          https://api.spotify.com/v1/audio-analysis/6kWx...
# danceability                                                      0.467
# duration                                                         211400
# energy                                                            0.608
# instrumentalness                                               0.000088
# key                                                                  10
# liveness                                                          0.125
# loudness                                                         -7.847
# mode                                                                  1
# speechiness                                                      0.0707
# tempo                                                         80.957001
# time_signature                                                        4
# valence                                                           0.108
# artistName                                                   The Weeknd
# release_year                                                       2020
# artist_embedding_0                                             0.002728
# artist_embedding_1                                            -0.000887
# artist_embedding_2                                             0.001375
# artist_embedding_3                                            -0.000885
# artist_embedding_4                                            -0.003587
# artist_embedding_5                                            -0.003667
# artist_embedding_6                                             0.001645
# artist_embedding_7                                             0.004389
# artist_embedding_8                                            -0.003223
# artist_embedding_9                                            -0.000698
# artist_embedding_10                                           -0.001632
# artist_embedding_11                                            0.000543
# artist_embedding_12                                           -0.004884
# artist_embedding_13                                           -0.004263
# artist_embedding_14                                           -0.002194
# artist_embedding_15                                           -0.002804
# artist_embedding_16                                           -0.003747
# artist_embedding_17                                           -0.003358
# artist_embedding_18                                           -0.001173
# artist_embedding_19                                           -0.004917
# artist_embedding_20                                           -0.002043
# artist_embedding_21                                            0.003366
# artist_embedding_22                                           -0.001567
# artist_embedding_23                                            0.000533
# artist_embedding_24                                           -0.003756
# artist_embedding_25                                            -0.00285
# artist_embedding_26                                            0.004546
# artist_embedding_27                                            0.001592
# artist_embedding_28                                            0.001944
# artist_embedding_29                                            -0.00018
# artist_embedding_30                                            0.002336
# artist_embedding_31                                            0.002176
# artist_embedding_32                                           -0.000776
# artist_embedding_33                                            0.003467
# artist_embedding_34                                            0.003154
# artist_embedding_35                                           -0.004681
# artist_embedding_36                                            0.001895
# artist_embedding_37                                            0.004411
# artist_embedding_38                                            0.002059
# artist_embedding_39                                            0.000113
# artist_embedding_40                                           -0.000471
# artist_embedding_41                                           -0.000426
# artist_embedding_42                                             -0.0046
# artist_embedding_43                                           -0.000419
# artist_embedding_44                                           -0.000526
# artist_embedding_45                                            0.004834
# artist_embedding_46                                           -0.001352
# artist_embedding_47                                           -0.004474
# artist_embedding_48                                           -0.004339
# artist_embedding_49                                           -0.000434
# artist_embedding_50                                           -0.000646
# artist_embedding_51                                            0.004178
# artist_embedding_52                                           -0.003159
# artist_embedding_53                                            0.002065
# artist_embedding_54                                            0.000672
# artist_embedding_55                                            0.000518
# artist_embedding_56                                           -0.001447
# artist_embedding_57                                           -0.002674
# artist_embedding_58                                           -0.000705
# artist_embedding_59                                           -0.003906
# artist_embedding_60                                             0.00265
# artist_embedding_61                                            0.004897
# artist_embedding_62                                           -0.001441
# artist_embedding_63                                           -0.001836
# artist_embedding_64                                           -0.000638
# artist_embedding_65                                            0.004635
# artist_embedding_66                                           -0.001587
# artist_embedding_67                                            0.003232
# artist_embedding_68                                            0.001363
# artist_embedding_69                                            0.002584
# artist_embedding_70                                           -0.004408
# artist_embedding_71                                            0.003535
# artist_embedding_72                                           -0.000637
# artist_embedding_73                                            0.002297
# artist_embedding_74                                            0.001507
# artist_embedding_75                                            0.001448
# artist_embedding_76                                            0.004061
# artist_embedding_77                                            0.004914
# artist_embedding_78                                           -0.002808
# artist_embedding_79                                           -0.001711
# artist_embedding_80                                            -0.00305
# artist_embedding_81                                           -0.000007
# artist_embedding_82                                             0.00033
# artist_embedding_83                                           -0.000255
# artist_embedding_84                                             0.00177
# artist_embedding_85                                           -0.003671
# artist_embedding_86                                              0.0007
# artist_embedding_87                                           -0.000685
# artist_embedding_88                                           -0.001238
# artist_embedding_89                                           -0.004443
# artist_embedding_90                                            0.000674
# artist_embedding_91                                            0.000154
# artist_embedding_92                                            0.001869
# artist_embedding_93                                            0.000463
# artist_embedding_94                                            0.000483
# artist_embedding_95                                           -0.000381
# artist_embedding_96                                           -0.000318
# artist_embedding_97                                           -0.002653
# artist_embedding_98                                            0.001394
# artist_embedding_99                                            0.004512
# artist_embedding_100                                          -0.002749
# artist_embedding_101                                           0.003502
# artist_embedding_102                                           0.004245
# artist_embedding_103                                           0.002241
# artist_embedding_104                                          -0.002142
# artist_embedding_105                                           0.001392
# artist_embedding_106                                           0.001519
# artist_embedding_107                                          -0.001058
# artist_embedding_108                                          -0.003844
# artist_embedding_109                                           0.001698
# artist_embedding_110                                             0.0021
# artist_embedding_111                                          -0.002586
# artist_embedding_112                                           0.001701
# artist_embedding_113                                            0.00065
# artist_embedding_114                                          -0.000949
# artist_embedding_115                                           0.003685
# artist_embedding_116                                           0.001563
# artist_embedding_117                                          -0.000343
# artist_embedding_118                                           0.000346
# artist_embedding_119                                           0.005139
# artist_embedding_120                                          -0.004426
# artist_embedding_121                                          -0.003701
# artist_embedding_122                                          -0.001456
# artist_embedding_123                                           0.002899
# artist_embedding_124                                           0.000154
# artist_embedding_125                                          -0.000329
# artist_embedding_126                                           0.002033
# artist_embedding_127                                           0.000334
# artist_embedding_128                                          -0.004198
# artist_embedding_129                                          -0.002882
# artist_embedding_130                                           0.002142
# artist_embedding_131                                           0.003431
# artist_embedding_132                                          -0.002801
# artist_embedding_133                                           0.003966
# artist_embedding_134                                          -0.000446
# artist_embedding_135                                           0.001306
# artist_embedding_136                                           0.004095
# artist_embedding_137                                           0.004972
# artist_embedding_138                                           0.000874
# artist_embedding_139                                           0.002442
# artist_embedding_140                                           0.003033
# artist_embedding_141                                          -0.000795
# artist_embedding_142                                           -0.00244
# artist_embedding_143                                          -0.001785
# artist_embedding_144                                          -0.003647
# artist_embedding_145                                           0.001244
# artist_embedding_146                                          -0.001861
# artist_embedding_147                                           0.003002
# artist_embedding_148                                          -0.000666
# artist_embedding_149                                           0.003949
# artist_embedding_150                                           0.002246
# artist_embedding_151                                          -0.003552
# artist_embedding_152                                          -0.000594
# artist_embedding_153                                          -0.002332
# artist_embedding_154                                           0.004953
# artist_embedding_155                                          -0.000299
# artist_embedding_156                                          -0.002513
# artist_embedding_157                                           0.002655
# artist_embedding_158                                           0.000538
# artist_embedding_159                                           0.001062
# artist_embedding_160                                          -0.000326
# artist_embedding_161                                           0.002847
# artist_embedding_162                                          -0.004413
# artist_embedding_163                                           0.000378
# artist_embedding_164                                          -0.000149
# artist_embedding_165                                          -0.001009
# artist_embedding_166                                          -0.003883
# artist_embedding_167                                           0.003012
# artist_embedding_168                                          -0.000799
# artist_embedding_169                                          -0.001896
# artist_embedding_170                                          -0.001291
# artist_embedding_171                                          -0.004093
# artist_embedding_172                                           0.004453
# artist_embedding_173                                          -0.000149
# artist_embedding_174                                           0.001038
# artist_embedding_175                                            0.00177
# artist_embedding_176                                          -0.003453
# artist_embedding_177                                          -0.004389
# artist_embedding_178                                           0.002002
# artist_embedding_179                                             0.0019
# artist_embedding_180                                           0.000462
# artist_embedding_181                                           0.003984
# artist_embedding_182                                           0.000966
# artist_embedding_183                                            0.00196
# artist_embedding_184                                           0.001232
# artist_embedding_185                                          -0.003391
# artist_embedding_186                                           0.001649
# artist_embedding_187                                          -0.001181
# artist_embedding_188                                           -0.00141
# artist_embedding_189                                          -0.000538
# artist_embedding_190                                           -0.00271
# artist_embedding_191                                          -0.004471
# artist_embedding_192                                           0.001905
# artist_embedding_193                                          -0.004968
# artist_embedding_194                                           0.002126
# artist_embedding_195                                          -0.001296
# artist_embedding_196                                          -0.000184
# artist_embedding_197                                           0.003023
# artist_embedding_198                                          -0.004166
# artist_embedding_199                                          -0.003577
# pop                                                                   1
# rock                                                                  0
# metal                                                                 0
# rap                                                                   0
# hip hop                                                               0
# classic                                                               0
# alt                                                                   0
# jazz                                                                  0
# indie                                                                 0
# others                                                                1
# time_signature_0                                                      0
# time_signature_1                                                      0
# time_signature_3                                                      0
# time_signature_4                                                      1
# time_signature_5                                                      0
# key_0                                                                 0
# key_1                                                                 0
# key_2                                                                 0
# key_3                                                                 0
# key_4                                                                 0
# key_5                                                                 0
# key_6                                                                 0
# key_7                                                                 0
# key_8                                                                 0
# key_9                                                                 0
# key_10                                                                1
# key_11                                                                0
# mode_0                                                                0
# mode_1                                                                1

# %%
similar_tracks = content_based_recommendation(MergedData.copy(), '6kWxIqQDsKFYCJGbU4AjCX', 100)

# %%
similar_tracks[['track_id', 'artistName']]
# Out:
#                        track_id                              artistName
# 2114513  6bnF93Rx87YqUBLSgjiMU8                              The Weeknd
# 2114510  4BGZF4oLbTL0pWm7C18pbv                              The Weeknd
# 2114518  40U8d12pC5UHqmHwXjHjjl                              The Weeknd
# 2114470  1gZADNt16Oh23jWyMYRk4p                              The Weeknd
# 2114472  7MXVkk9YMctZqd1Srtv4MB                              The Weeknd
# 2114489  3dhjNA0jGA8vHBQ1VdD6vV                              The Weeknd
# 2114506  5oAOK7xCJD8hzp9PuxjULL                              The Weeknd
# 2114448  7eZ7ODAt9cALYnWLO8F6Fd                              The Weeknd
# 2114458  03j354P848KtNU2FVSwkDG                              The Weeknd
# 2114476  36YCdzT57us0LhDmCYtrNE                              The Weeknd
# 2114468  3H3qBumaYj67PT3aMEBvAP                              The Weeknd
# 2114447  4fLnXd56RsWN4ZBtb9TegQ                              The Weeknd
# 2114495  0Nwar8rweBUyfyuoyjjUvk                              The Weeknd
# 2114494  6QdnKD1zwEgyOWtkrdzlOF                              The Weeknd
